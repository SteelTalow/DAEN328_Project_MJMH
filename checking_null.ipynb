# %%
import pandas as pd

# %%
df = pd.read_csv("cleaned_taxidata.csv")

# %%
df.head()
# Out:
#    vendorid  passenger_count  trip_distance  pulocationid  dolocationid  \
# 0       1.0              1.0            1.5           151           239
# 1       1.0              1.0            2.6           239           246
# 2       2.0              3.0            0.0           236           236
# 3       2.0              5.0            0.0           193           193
# 4       2.0              5.0            0.0           193           193
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0           1.0          7.0    0.5      0.5        1.65           0.0
# 1           1.0         14.0    0.5      0.5        1.00           0.0
# 2           1.0          4.5    0.5      0.5        0.00           0.0
# 3           2.0          3.5    0.5      0.5        0.00           0.0
# 4           2.0         52.0    0.0      0.5        0.00           0.0
#
#    improvement_surcharge  total_amount pickup_date pickup_time dropoff_date  \
# ...

# %%
null_or_empty = df.isnull() | (df == '')

rowwise_missing = null_or_empty.apply(lambda row: list(row.index[row]), axis=1)

rows_with_missing = rowwise_missing[rowwise_missing.apply(len) > 0]

print(rows_with_missing.head(10))
# Out:
# Series([], dtype: object)

# %%
null_or_empty_per_column = (df.isnull() | (df == '')).sum()

# Display nicely sorted
print(null_or_empty_per_column.sort_values(ascending=False))
# Out:
# vendorid                 0
# passenger_count          0
# dropoff_time             0
# dropoff_date             0
# pickup_time              0
# pickup_date              0
# total_amount             0
# improvement_surcharge    0
# tolls_amount             0
# tip_amount               0
# mta_tax                  0
# extra                    0
# fare_amount              0
# payment_type             0
# dolocationid             0
# pulocationid             0
# trip_distance            0
# total_time               0
# dtype: int64
